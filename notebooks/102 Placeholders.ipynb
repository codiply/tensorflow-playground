# %%
import tensorflow as tf

# %%
def run_and_print(x, dictionary):
    with tf.Session() as sess:
        result = sess.run(x, feed_dict=dictionary)
        print(result)

# %% [markdown]
# ### Placeholders

# %%
x = tf.placeholder("float", 3)

# %%
y = x * 2

# %%
run_and_print(y, {x: [1,2,3]})
# Out:
# [ 2.  4.  6.]

# %%
x = tf.placeholder("float", None)

# %%
y = x * 2

# %%
run_and_print(y, {x: [1,2,3,4]})
# Out:
# [ 2.  4.  6.  8.]

# %%
run_and_print(y, {x: [[1,2,3],[4,5,6]]})
# Out:
# [[  2.   4.   6.]
#  [  8.  10.  12.]]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import urllib
import os

# %%
data_folder = "./data"

# %%
if not os.path.exists(data_folder):
    os.mkdir(data_folder)

# %%
image_filename = os.path.join(data_folder, "MarshOrchid.jpg")
if not os.path.exists(image_filename):
    image_url = "http://learningtensorflow.com/images/MarshOrchid.jpg"
    urllib.urlretrieve(image_url, image_filename)

# %%
image_data = mpimg.imread(image_filename)

# %%
plt.imshow(image_data)
plt.show()

# %%
image = tf.placeholder("uint8", [None, None, 3])
slice = tf.slice(image, [1000, 0, 0], [3000, -1, -1])

with tf.Session() as session:
    result = session.run(slice, feed_dict={image: image_data})
    print(result.shape)
    

plt.imshow(result)
plt.show()
# Out:
# (3000, 3685, 3)
